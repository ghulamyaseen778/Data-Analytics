# %%
Quiz_data = [
    {
        "id":"1",
       "q":"What is a correct syntax to output 'Hello World' in Python?",
        "options":{
            "a":"print('Hello, World!')",
            "b":"echo 'Hello, World!'",
            "c":"printf('Hello, World!')",
            "d":"console.log('Hello, World!')",
        },
        "correct":"a"
    },
    {"id":"2",
       "q":"What data type is returned by type(5.0) in Python?",
        "options":{
            "a":"int",
            "b":"str",
            "c":"float",
            "d":"bool",
        },
        "correct":"c"
    },
    {"id":"3",
       "q":"Which keyword is used to create a function in Python?",
        "options":{
            "a":"function",
            "b":"define",
            "c":"func",
            "d":"def",
        },
        "correct":"d"
    },
    {"id":"4",
       "q":"What will the following code output? \n print(2 ** 3)",
        "options":{
            "a":"6",
            "b":"8",
            "c":"9",
            "d":"5",
        },
        "correct":"b"
    },
    {"id":"5",
       "q":"Which of these is a valid variable name in Python?",
        "options":{
            "a":"1variable",
            "b":"variable",
            "c":"_variable",
            "d":"variable name",
        },
        "correct":"c"
    },
    {"id":"6",
       "q":"What will this code output? \n my_list = [1, 2, 3] \n print(my_list[1])",
        "options":{
            "a":"1",
            "b":"2",
            "c":"3",
            "d":"IndexError",
        },
        "correct":"b"
    },
    {"id":"7",
       "q":"What does the len() function return when used with a string?",
        "options":{
            "a":"The number of vowels in the string.",
            "b":"The number of words in the string.",
            "c":"The number of characters in the string.",
            "d":"An error.",
        },
        "correct":"c"
    },
    {"id":"8",
       "q":"Which of the following is not a Python data structure?",
        "options":{
            "a":"list",
            "b":"set",
            "c":"tuple",
            "d":"graph",
        },
        "correct":"d"
    },
    {"id":"9",
       "q":"What will the following code output? \n x = True \n y = False \n print(x and y)",
        "options":{
            "a":"True",
            "b":"False",
            "c":"None",
            "d":"Error",
        },
        "correct":"b"
    },
    {"id":"10",
       "q":"What will the following code output? \n for i in range(1, 5):\n  print(i, end=" ")",
        "options":{
            "a":"1 2 3 4",
            "b":"1 2 3 4 5",
            "c":"0 1 2 3 4",
            "d":"0 1 2 3 4 5",
        },
        "correct":"a"
    },
]

# %%
print("Your quiz started you have 10 questions")
answers = []
print("\n")
for question in Quiz_data:
    print(question["q"])
    print(f"a. {question["options"]["a"]}    b. {question["options"]["b"]}")
    print(f"c. {question["options"]["c"]}    d. {question["options"]["d"]}")
    userInput = input("Select Your Option: ")
    print("\n")
    answers.append({"id":question["id"],"correct":userInput.lower() == question["correct"]})

print(f"Your Total Score is: {len([i for i in answers if i["correct"]==True])}")
# Out:
# Your quiz started you have 10 questions
#
#
# What is a correct syntax to output 'Hello World' in Python?
# a. print('Hello, World!')    b. echo 'Hello, World!'
# c. printf('Hello, World!')    d. console.log('Hello, World!')
#
#
# What data type is returned by type(5.0) in Python?
# a. int    b. str
# c. float    d. bool
#
#
# Which keyword is used to create a function in Python?
# a. function    b. define
# c. func    d. def
#
#
# What will the following code output?
#  print(2 ** 3)
# a. 6    b. 8
# c. 9    d. 5
#
#
# Which of these is a valid variable name in Python?
# a. 1variable    b. variable
# c. _variable    d. variable name
#
#
# What will this code output?
#  my_list = [1, 2, 3]
#  print(my_list[1])
# a. 1    b. 2
# c. 3    d. IndexError
#
#
# What does the len() function return when used with a string?
# a. The number of vowels in the string.    b. The number of words in the string.
# c. The number of characters in the string.    d. An error.
#
#
# ...
